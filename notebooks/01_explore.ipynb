# %%
# 📘 notebooks/01_explore.ipynb

# --- 1. Import Libraries ---
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
import numpy as np

# --- 2. Define Data Paths ---
data_path = "../data/raw"
classes = os.listdir(data_path)
print("Available Classes:", classes)

# --- 3. Count Images per Class ---
counts = {}
for cls in classes:
    path = os.path.join(data_path, cls)
    counts[cls] = len(os.listdir(path))
    
plt.figure(figsize=(10,5))
sns.barplot(x=list(counts.keys()), y=list(counts.values()))
plt.title("Number of Images per Class")
plt.xlabel("Class")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# --- 4. Display Sample Images ---
n = 3
plt.figure(figsize=(12,6))
for i, cls in enumerate(classes[:n]):
    img_path = os.path.join(data_path, cls, os.listdir(os.path.join(data_path, cls))[0])
    img = Image.open(img_path)
    plt.subplot(1, n, i+1)
    plt.imshow(img)
    plt.title(cls)
    plt.axis("off")
plt.show()

# --- 5. Print Summary ---
total_images = sum(counts.values())
print(f"Total Images: {total_images}")
print(f"Classes: {len(classes)}")
# Out:
# Available Classes: ['Tomato_Bacterial_spot', 'Tomato_Early_blight', 'Tomato_healthy', 'Tomato_Late_blight', 'Tomato_Leaf_Mold']
# Total Images: 7579
# Classes: 5
